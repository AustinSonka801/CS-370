# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.990025, score: 22
# Scores: (min: 22, avg: 22, max: 22)
#
# Run: 2, exploration: 0.8822202429488013, score: 24
# Scores: (min: 22, avg: 23, max: 24)
#
# Run: 3, exploration: 0.810157377815473, score: 18
# Scores: (min: 18, avg: 21.333333333333332, max: 24)
#
# Run: 4, exploration: 0.7514768435208588, score: 16
# Scores: (min: 16, avg: 20, max: 24)
#
# Run: 5, exploration: 0.7076077347272662, score: 13
# Scores: (min: 13, avg: 18.6, max: 24)
#
# Run: 6, exploration: 0.6465587967553006, score: 19
# Scores: (min: 13, avg: 18.666666666666668, max: 24)
#
# Run: 7, exploration: 0.6118738784280476, score: 12
# Scores: (min: 12, avg: 17.714285714285715, max: 24)
#
# Run: 8, exploration: 0.567555222460375, score: 16
# Scores: (min: 12, avg: 17.5, max: 24)
#
# Run: 9, exploration: 0.5398075216808175, score: 11
# Scores: (min: 11, avg: 16.77777777777778, max: 24)
#
# Run: 10, exploration: 0.5057535983897912, score: 14
# Scores: (min: 11, avg: 16.5, max: 24)
#
# Run: 11, exploration: 0.483444593917636, score: 10
# Scores: (min: 10, avg: 15.909090909090908, max: 24)
#
# Run: 12, exploration: 0.46211964903917074, score: 10
# Scores: (min: 10, avg: 15.416666666666666, max: 24)
#
# Run: 13, exploration: 0.3995984329713264, score: 30
# Scores: (min: 10, avg: 16.53846153846154, max: 30)
#
# Run: 14, exploration: 0.37251769488706843, score: 15
# Scores: (min: 10, avg: 16.428571428571427, max: 30)
#
# Run: 15, exploration: 0.3543053533848483, score: 11
# Scores: (min: 10, avg: 16.066666666666666, max: 30)
#
# Run: 16, exploration: 0.31890579420988907, score: 22
# Scores: (min: 10, avg: 16.4375, max: 30)
#
# Run: 17, exploration: 0.2730095965279488, score: 32
# Scores: (min: 10, avg: 17.352941176470587, max: 32)
#
# Run: 18, exploration: 0.21355457002808648, score: 50
# Scores: (min: 10, avg: 19.166666666666668, max: 50)
#
# Run: 19, exploration: 0.192217783647157, score: 22
# Scores: (min: 10, avg: 19.31578947368421, max: 50)
#
# Run: 20, exploration: 0.1730128104744653, score: 22
# Scores: (min: 10, avg: 19.45, max: 50)
#
# Run: 21, exploration: 0.14960551470448571, score: 30
# Scores: (min: 10, avg: 19.952380952380953, max: 50)
#
# Run: 22, exploration: 0.12059799144222175, score: 44
# Scores: (min: 10, avg: 21.045454545454547, max: 50)
#
# Run: 23, exploration: 0.0888276147181114, score: 62
# Scores: (min: 10, avg: 22.82608695652174, max: 62)
#
# Run: 24, exploration: 0.07490878371492794, score: 35
# Scores: (min: 10, avg: 23.333333333333332, max: 62)
#
# Run: 25, exploration: 0.0494138221100385, score: 84
# Scores: (min: 10, avg: 25.76, max: 84)

# %% [markdown]
# og code

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.05  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9511101304657719, score: 30
# Scores: (min: 30, avg: 30, max: 30)
#
# Run: 2, exploration: 0.9137248860125932, score: 9
# Scores: (min: 9, avg: 19.5, max: 30)
#
# Run: 3, exploration: 0.653073201944699, score: 68
# Scores: (min: 9, avg: 35.666666666666664, max: 68)
#
# Run: 4, exploration: 0.4907693883854626, score: 58
# Scores: (min: 9, avg: 41.25, max: 68)
#
# Run: 5, exploration: 0.37627099809304654, score: 54
# Scores: (min: 9, avg: 43.8, max: 68)
#
# Run: 6, exploration: 0.32864265128599696, score: 28
# Scores: (min: 9, avg: 41.166666666666664, max: 68)
#
# Run: 7, exploration: 0.2913921604631864, score: 25
# Scores: (min: 9, avg: 38.857142857142854, max: 68)
#
# Run: 8, exploration: 0.2757603055760701, score: 12
# Scores: (min: 9, avg: 35.5, max: 68)
#
# Run: 9, exploration: 0.2532352299289372, score: 18
# Scores: (min: 9, avg: 33.55555555555556, max: 68)
#
# Run: 10, exploration: 0.2408545925762412, score: 11
# Scores: (min: 9, avg: 31.3, max: 68)
#
# Run: 11, exploration: 0.2290792429684691, score: 11
# Scores: (min: 9, avg: 29.454545454545453, max: 68)
#
# Run: 12, exploration: 0.21355457002808648, score: 15
# Scores: (min: 9, avg: 28.25, max: 68)
#
# Run: 13, exploration: 0.16957841978827493, score: 47
# Scores: (min: 9, avg: 29.692307692307693, max: 68)
#
# Run: 14, exploration: 0.15967890763313974, score: 13
# Scores: (min: 9, avg: 28.5, max: 68)
#
# Run: 15, exploration: 0.13669828187021155, score: 32
# Scores: (min: 9, avg: 28.733333333333334, max: 68)
#
# Run: 16, exploration: 0.13066846301911936, score: 10
# Scores: (min: 9, avg: 27.5625, max: 68)
#
# Run: 17, exploration: 0.11299003011401039, score: 30
# Scores: (min: 9, avg: 27.705882352941178, max: 68)
#
# Run: 18, exploration: 0.09153970651645797, score: 43
# Scores: (min: 9, avg: 28.555555555555557, max: 68)
#
# Run: 19, exploration: 0.08750185146499175, score: 10
# Scores: (min: 9, avg: 27.57894736842105, max: 68)
#
# Run: 20, exploration: 0.07797369223798889, score: 24
# Scores: (min: 9, avg: 27.4, max: 68)
#
# Run: 21, exploration: 0.07305469791585968, score: 14
# Scores: (min: 9, avg: 26.761904761904763, max: 68)
#
# Run: 22, exploration: 0.0667518955258533, score: 19
# Scores: (min: 9, avg: 26.40909090909091, max: 68)
#
# Run: 23, exploration: 0.061607401965086545, score: 17
# Scores: (min: 9, avg: 26, max: 68)
#
# Run: 24, exploration: 0.05327239673939179, score: 30
# Scores: (min: 9, avg: 26.166666666666668, max: 68)
#
# Run: 25, exploration: 0.04892091923449087, score: 18
# Scores: (min: 9, avg: 25.84, max: 68)
#
# Run: 26, exploration: 0.046997986793891174, score: 9
# Scores: (min: 9, avg: 25.192307692307693, max: 68)
#
# Run: 27, exploration: 0.04063952250178857, score: 30
# Scores: (min: 9, avg: 25.37037037037037, max: 68)
#
# Run: 28, exploration: 0.0386526615487428, score: 11
# Scores: (min: 9, avg: 24.857142857142858, max: 68)
#
# Run: 29, exploration: 0.03496560272750046, score: 21
# Scores: (min: 9, avg: 24.724137931034484, max: 68)
#
# Run: 30, exploration: 0.03308985827710748, score: 12
# Scores: (min: 9, avg: 24.3, max: 68)
#
# Run: 31, exploration: 0.030083851847510768, score: 20
# Scores: (min: 9, avg: 24.161290322580644, max: 68)
#
# Run: 32, exploration: 0.028186002814352063, score: 14
# Scores: (min: 9, avg: 23.84375, max: 68)
#
# Run: 33, exploration: 0.02536986677519817, score: 22
# Scores: (min: 9, avg: 23.78787878787879, max: 68)
#
# Run: 34, exploration: 0.022158551474944856, score: 28
# Scores: (min: 9, avg: 23.91176470588235, max: 68)
#
# Run: 35, exploration: 0.020553584742122436, score: 16
# Scores: (min: 9, avg: 23.685714285714287, max: 68)
#
# Run: 36, exploration: 0.01964695745288379, score: 10
# Scores: (min: 9, avg: 23.305555555555557, max: 68)
#
# Run: 37, exploration: 0.018780321875645996, score: 10
# Scores: (min: 9, avg: 22.945945945945947, max: 68)
#
# Run: 38, exploration: 0.0175075817047932, score: 15
# Scores: (min: 9, avg: 22.736842105263158, max: 68)
#
# Run: 39, exploration: 0.01681941195362342, score: 9
# Scores: (min: 9, avg: 22.384615384615383, max: 68)
#
# Run: 40, exploration: 0.01567956241402325, score: 15
# Scores: (min: 9, avg: 22.2, max: 68)
#
# Run: 41, exploration: 0.014987930304771725, score: 10
# Scores: (min: 9, avg: 21.902439024390244, max: 68)
#
# Run: 42, exploration: 0.014183896485845416, score: 12
# Scores: (min: 9, avg: 21.666666666666668, max: 68)
#
# Run: 43, exploration: 0.012960179199743523, score: 19
# Scores: (min: 9, avg: 21.6046511627907, max: 68)
#
# Run: 44, exploration: 0.012388500230681249, score: 10
# Scores: (min: 9, avg: 21.34090909090909, max: 68)
#
# Run: 45, exploration: 0.01184203826198843, score: 10
# Scores: (min: 9, avg: 21.08888888888889, max: 68)
#
# Run: 46, exploration: 0.011263082556340478, score: 11
# Scores: (min: 9, avg: 20.869565217391305, max: 68)
#
# Run: 47, exploration: 0.010766263235786683, score: 10
# Scores: (min: 9, avg: 20.638297872340427, max: 68)
#
# Run: 48, exploration: 0.01029135882494263, score: 10
# Scores: (min: 9, avg: 20.416666666666668, max: 68)
#
# Run: 49, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 20.367346938775512, max: 68)
#
# Run: 50, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 20.2, max: 68)
#
# Run: 51, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 20.274509803921568, max: 68)
#
# Run: 52, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 20.25, max: 68)
#
# Run: 53, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 20.41509433962264, max: 68)
#
# Run: 54, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 20.203703703703702, max: 68)
#
# Run: 55, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 20.01818181818182, max: 68)
#
# Run: 56, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 19.839285714285715, max: 68)
#
# Run: 57, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 19.666666666666668, max: 68)
#
# Run: 58, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 19.5, max: 68)
#
# Run: 59, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 19.47457627118644, max: 68)
#
# Run: 60, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 19.35, max: 68)
#
# Run: 61, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 19.81967213114754, max: 68)
#
# Run: 62, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 20.129032258064516, max: 68)
#
# Run: 63, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 19.96825396825397, max: 68)
#
# Run: 64, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 19.8125, max: 68)
#
# Run: 65, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 19.846153846153847, max: 68)
#
# Run: 66, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 19.71212121212121, max: 68)
#
# Run: 67, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 19.671641791044777, max: 68)
#
# Run: 68, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 19.61764705882353, max: 68)
#
# Run: 69, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 19.652173913043477, max: 68)
#
# Run: 70, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 19.514285714285716, max: 68)
#
# Run: 71, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 19.830985915492956, max: 68)
#
# Run: 72, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 19.680555555555557, max: 68)
#
# Run: 73, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 19.589041095890412, max: 68)
#
# Run: 74, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 19.527027027027028, max: 68)
#
# Run: 75, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.373333333333335, max: 68)
#
# Run: 76, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.25, max: 68)
#
# Run: 77, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 19.350649350649352, max: 68)
#
# Run: 78, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.26923076923077, max: 68)
#
# Run: 79, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.21518987341772, max: 68)
#
# Run: 80, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.1, max: 68)
#
# Run: 81, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19, max: 68)
#
# Run: 82, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.890243902439025, max: 68)
#
# Run: 83, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.89156626506024, max: 68)
#
# Run: 84, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.773809523809526, max: 68)
#
# Run: 85, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.67058823529412, max: 68)
#
# Run: 86, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.558139534883722, max: 68)
#
# Run: 87, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.45977011494253, max: 68)
#
# Run: 88, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.420454545454547, max: 68)
#
# Run: 89, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.314606741573034, max: 68)
#
# Run: 90, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.266666666666666, max: 68)
#
# Run: 91, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.164835164835164, max: 68)
#
# Run: 92, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.065217391304348, max: 68)
#
# Run: 93, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18, max: 68)
#
# Run: 94, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.97872340425532, max: 68)
#
# Run: 95, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.88421052631579, max: 68)
#
# Run: 96, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.822916666666668, max: 68)
#
# Run: 97, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.804123711340207, max: 68)
#
# Run: 98, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.744897959183675, max: 68)
#
# Run: 99, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.656565656565657, max: 68)
#
# Run: 100, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.57, max: 68)
#
# Run: 101, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.38, max: 68)
#
# Run: 102, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.38, max: 68)
#
# Run: 103, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.92, max: 58)
#
# Run: 104, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.47, max: 54)
#
# Run: 105, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.02, max: 48)
#
# Run: 106, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.83, max: 48)
#
# Run: 107, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 15.81, max: 48)
#
# Run: 108, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.78, max: 48)
#
# Run: 109, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.69, max: 48)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.68, max: 48)
#
# Run: 111, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 16.03, max: 48)
#
# Run: 112, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.98, max: 48)
#
# Run: 113, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.59, max: 48)
#
# Run: 114, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.55, max: 48)
#
# Run: 115, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.35, max: 48)
#
# Run: 116, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.36, max: 48)
#
# Run: 117, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.16, max: 48)
#
# Run: 118, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.82, max: 48)
#
# Run: 119, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.83, max: 48)
#
# Run: 120, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.71, max: 48)
#
# Run: 121, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.69, max: 48)
#
# Run: 122, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.71, max: 48)
#
# Run: 123, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.71, max: 48)
#
# Run: 124, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.56, max: 48)
#
# Run: 125, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.49, max: 48)
#
# Run: 126, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.61, max: 48)
#
# Run: 127, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.44, max: 48)
#
# Run: 128, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.47, max: 48)
#
# Run: 129, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.35, max: 48)
#
# Run: 130, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.32, max: 48)
#
# Run: 131, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.22, max: 48)
#
# Run: 132, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.17, max: 48)
#
# Run: 133, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.04, max: 48)
#
# Run: 134, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.88, max: 48)
#
# Run: 135, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.83, max: 48)
#
# Run: 136, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.92, max: 48)
#
# Run: 137, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.9, max: 48)
#
# Run: 138, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.84, max: 48)
#
# Run: 139, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.86, max: 48)
#
# Run: 140, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.8, max: 48)
#
# Run: 141, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.8, max: 48)
#
# Run: 142, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.81, max: 48)
#
# Run: 143, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.76, max: 48)
#
# Run: 144, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.75, max: 48)
#
# Run: 145, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.77, max: 48)
#
# Run: 146, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.78, max: 48)
#
# Run: 147, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.78, max: 48)
#
# Run: 148, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.77, max: 48)
#
# Run: 149, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.68, max: 48)
#
# Run: 150, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.65, max: 48)
#
# Run: 151, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.51, max: 48)
#
# Run: 152, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.41, max: 48)
#
# Run: 153, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.21, max: 48)
#
# Run: 154, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.31, max: 48)
#
# Run: 155, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 13.49, max: 48)
#
# Run: 156, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.53, max: 48)
#
# Run: 157, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.54, max: 48)
#
# Run: 158, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.54, max: 48)
#
# Run: 159, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 13.52, max: 48)
#
# Run: 160, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.49, max: 48)
#
# Run: 161, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.1, max: 46)
#
# Run: 162, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.82, max: 46)
#
# Run: 163, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.81, max: 46)
#
# Run: 164, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.81, max: 46)
#
# Run: 165, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.68, max: 46)
#
# Run: 166, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.68, max: 46)
#
# Run: 167, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.6, max: 46)
#
# Run: 168, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.56, max: 46)
#
# Run: 169, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.47, max: 46)
#
# Run: 170, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.51, max: 46)
#
# Run: 171, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.18, max: 46)
#
# Run: 172, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.17, max: 46)
#
# Run: 173, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.14, max: 46)
#
# Run: 174, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.08, max: 46)
#
# Run: 175, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.22, max: 46)
#
# Run: 176, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.22, max: 46)
#
# Run: 177, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.05, max: 46)
#
# Run: 178, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.01, max: 46)
#
# Run: 179, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.07, max: 46)
#
# Run: 180, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.07, max: 46)
#
# Run: 181, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.07, max: 46)
#
# Run: 182, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.13, max: 46)
#
# Run: 183, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.04, max: 46)
#
# Run: 184, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.03, max: 46)
#
# Run: 185, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.03, max: 46)
#
# Run: 186, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.08, max: 46)
#
# Run: 187, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.07, max: 46)
#
# Run: 188, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.02, max: 46)
#
# Run: 189, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.11, max: 46)
#
# Run: 190, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.08, max: 46)
#
# Run: 191, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.09, max: 46)
#
# Run: 192, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.09, max: 46)
#
# Run: 193, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.09, max: 46)
#
# Run: 194, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.04, max: 46)
#
# Run: 195, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.04, max: 46)
#
# Run: 196, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.05, max: 46)
#
# Run: 197, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.99, max: 46)
#
# Run: 198, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.97, max: 46)
#
# Run: 199, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.98, max: 46)
#
# Run: 200, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.08, max: 46)
#
# Run: 201, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.06, max: 46)
#
# Run: 202, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 12.29, max: 46)
#
# Run: 203, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.18, max: 46)
#
# Run: 204, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.14, max: 46)
#
# Run: 205, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.21, max: 46)
#
# Run: 206, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.28, max: 46)
#
# Run: 207, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.14, max: 46)
#
# Run: 208, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.13, max: 46)
#
# Run: 209, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.14, max: 46)
#
# Run: 210, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.22, max: 46)
#
# Run: 211, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.96, max: 32)
#
# Run: 212, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.96, max: 32)
#
# Run: 213, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.98, max: 32)
#
# Run: 214, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.01, max: 32)
#
# Run: 215, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12, max: 32)
#
# Run: 216, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.09, max: 32)
#
# Run: 217, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.12, max: 32)
#
# Run: 218, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.19, max: 32)
#
# Run: 219, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.26, max: 32)
#
# Run: 220, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.27, max: 32)
#
# Run: 221, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.25, max: 32)
#
# Run: 222, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.24, max: 32)
#
# Run: 223, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.19, max: 32)
#
# Run: 224, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.25, max: 32)
#
# Run: 225, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 12.43, max: 32)
#
# Run: 226, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.31, max: 32)
#
# Run: 227, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.28, max: 32)
#
# Run: 228, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.26, max: 32)
#
# Run: 229, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.29, max: 32)
#
# Run: 230, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.4, max: 32)
#
# Run: 231, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.42, max: 32)
#
# Run: 232, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.44, max: 32)
#
# Run: 233, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 12.63, max: 32)
#
# Run: 234, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.68, max: 32)
#
# Run: 235, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.66, max: 32)
#
# Run: 236, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.6, max: 32)
#
# Run: 237, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.62, max: 32)
#
# Run: 238, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.64, max: 32)
#
# Run: 239, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.61, max: 32)
#
# Run: 240, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.66, max: 32)
#
# Run: 241, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.67, max: 32)
#
# Run: 242, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.73, max: 32)
#
# Run: 243, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.69, max: 32)
#
# Run: 244, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 13.04, max: 44)
#
# Run: 245, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.04, max: 44)
#
# Run: 246, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.01, max: 44)
#
# Run: 247, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.05, max: 44)
#
# Run: 248, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.11, max: 44)
#
# Run: 249, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.11, max: 44)
#
# Run: 250, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 13.2, max: 44)
#
# Run: 251, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 13.48, max: 44)
#
# Run: 252, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.47, max: 44)
#
# Run: 253, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.47, max: 44)
#
# Run: 254, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.39, max: 44)
#
# Run: 255, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 13.51, max: 44)
#
# Run: 256, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.46, max: 44)
#
# Run: 257, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 13.62, max: 44)
#
# Run: 258, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.61, max: 44)
#
# Run: 259, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.53, max: 44)
#
# Run: 260, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.55, max: 44)
#
# Run: 261, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.55, max: 44)
#
# Run: 262, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.53, max: 44)
#
# Run: 263, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.55, max: 44)
#
# Run: 264, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.55, max: 44)
#
# Run: 265, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.58, max: 44)
#
# Run: 266, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.55, max: 44)
#
# Run: 267, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 13.62, max: 44)
#
# Run: 268, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.59, max: 44)
#
# Run: 269, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.55, max: 44)
#
# Run: 270, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.49, max: 44)
#
# Run: 271, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.53, max: 44)
#
# Run: 272, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.54, max: 44)
#
# Run: 273, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 13.91, max: 47)
#
# Run: 274, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.94, max: 47)
#
# Run: 275, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.81, max: 47)
#
# Run: 276, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 13.99, max: 47)
#
# Run: 277, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14, max: 47)
#
# Run: 278, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 14.24, max: 47)
#
# Run: 279, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.15, max: 47)
#
# Run: 280, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.14, max: 47)
#
# Run: 281, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.29, max: 47)
#
# Run: 282, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.24, max: 47)
#
# Run: 283, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.23, max: 47)
#
# Run: 284, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 14.42, max: 47)
#
# Run: 285, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.43, max: 47)
#
# Run: 286, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.48, max: 47)
#
# Run: 287, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.56, max: 47)
#
# Run: 288, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.57, max: 47)
#
# Run: 289, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.53, max: 47)
#
# Run: 290, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.61, max: 47)
#
# Run: 291, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 14.76, max: 47)
#
# Run: 292, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 14.89, max: 47)
#
# Run: 293, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.86, max: 47)
#
# Run: 294, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 14.97, max: 47)
#
# Run: 295, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 15.09, max: 47)
#
# Run: 296, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.06, max: 47)
#
# Run: 297, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.06, max: 47)
#
# Run: 298, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.05, max: 47)
#
# Run: 299, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.05, max: 47)
#
# Run: 300, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.96, max: 47)
#
# Run: 301, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.98, max: 47)
#
# Run: 302, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.86, max: 47)
#
# Run: 303, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 14.99, max: 47)
#
# Run: 304, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15, max: 47)
#
# Run: 305, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.93, max: 47)
#
# Run: 306, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.98, max: 47)
#
# Run: 307, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.98, max: 47)
#
# Run: 308, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.99, max: 47)
#
# Run: 309, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.08, max: 47)
#
# Run: 310, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.03, max: 47)
#
# Run: 311, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.93, max: 47)
#
# Run: 312, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.93, max: 47)
#
# Run: 313, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.92, max: 47)
#
# Run: 314, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.9, max: 47)
#
# Run: 315, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.89, max: 47)
#
# Run: 316, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.86, max: 47)
#
# Run: 317, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 15, max: 47)
#
# Run: 318, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.96, max: 47)
#
# Run: 319, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.89, max: 47)
#
# Run: 320, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 15.03, max: 47)
#
# Run: 321, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 15.18, max: 47)
#
# Run: 322, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.08, max: 47)
#
# Run: 323, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.08, max: 47)
#
# Run: 324, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.98, max: 47)
#
# Run: 325, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.79, max: 47)
#
# Run: 326, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.79, max: 47)
#
# Run: 327, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.88, max: 47)
#
# Run: 328, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 15.12, max: 47)
#
# Run: 329, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.1, max: 47)
#
# Run: 330, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.02, max: 47)
#
# Run: 331, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.01, max: 47)
#
# Run: 332, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15, max: 47)
#
# Run: 333, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.83, max: 47)
#
# Run: 334, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.75, max: 47)
#
# Run: 335, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.8, max: 47)
#
# Run: 336, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.83, max: 47)
#
# Run: 337, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.86, max: 47)
#
# Run: 338, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.86, max: 47)
#
# Run: 339, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.87, max: 47)
#
# Run: 340, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.82, max: 47)
#
# Run: 341, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.8, max: 47)
#
# Run: 342, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 14.92, max: 47)
#
# Run: 343, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.92, max: 47)
#
# Run: 344, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.59, max: 47)
#
# Run: 345, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.62, max: 47)
#
# Run: 346, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.63, max: 47)
#
# Run: 347, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.61, max: 47)
#
# Run: 348, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.59, max: 47)
#
# Run: 349, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.61, max: 47)
#
# Run: 350, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.52, max: 47)
#
# Run: 351, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.34, max: 47)
#
# Run: 352, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.36, max: 47)
#
# Run: 353, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.47, max: 47)
#
# Run: 354, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.45, max: 47)
#
# Run: 355, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.15, max: 47)
#
# Run: 356, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.15, max: 47)
#
# Run: 357, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.04, max: 47)
#
# Run: 358, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.04, max: 47)
#
# Run: 359, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.17, max: 47)
#
# Run: 360, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.18, max: 47)
#
# Run: 361, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.19, max: 47)
#
# Run: 362, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.28, max: 47)
#
# Run: 363, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.25, max: 47)
#
# Run: 364, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.24, max: 47)
#
# Run: 365, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.22, max: 47)
#
# Run: 366, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.26, max: 47)
#
# Run: 367, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.18, max: 47)
#
# Run: 368, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.17, max: 47)
#
# Run: 369, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.19, max: 47)
#
# Run: 370, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.2, max: 47)
#
# Run: 371, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.18, max: 47)
#
# Run: 372, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.28, max: 47)
#
# Run: 373, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.91, max: 36)
#
# Run: 374, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.91, max: 36)
#
# Run: 375, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 13.98, max: 36)
#
# Run: 376, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.78, max: 36)
#
# Run: 377, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.76, max: 36)
#
# Run: 378, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.52, max: 36)
#
# Run: 379, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.53, max: 36)
#
# Run: 380, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.54, max: 36)
#
# Run: 381, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.39, max: 36)
#
# Run: 382, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.41, max: 36)
#
# Run: 383, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.52, max: 36)
#
# Run: 384, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.35, max: 36)
#
# Run: 385, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 13.47, max: 36)
#
# Run: 386, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.41, max: 36)
#
# Run: 387, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.33, max: 36)
#
# Run: 388, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.32, max: 36)
#
# Run: 389, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 13.39, max: 36)
#
# Run: 390, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.44, max: 36)
#
# Run: 391, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.29, max: 36)
#
# Run: 392, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.15, max: 36)
#
# Run: 393, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.16, max: 36)
#
# Run: 394, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.05, max: 36)
#
# Run: 395, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.95, max: 36)
#
# Run: 396, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.97, max: 36)
#
# Run: 397, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.97, max: 36)
#
# Run: 398, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.97, max: 36)
#
# Run: 399, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.97, max: 36)
#
# Run: 400, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.96, max: 36)
#
# Run: 401, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.94, max: 36)
#
# Run: 402, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.84, max: 36)
#
# Run: 403, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.71, max: 36)
#
# Run: 404, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.73, max: 36)
#
# Run: 405, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.79, max: 36)
#
# Run: 406, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.67, max: 36)
#
# Run: 407, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.7, max: 36)
#
# Run: 408, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.75, max: 36)
#
# Run: 409, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 12.87, max: 36)
#
# Run: 410, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.89, max: 36)
#
# Run: 411, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.98, max: 36)
#
# Run: 412, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.96, max: 36)
#
# Run: 413, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13, max: 36)
#
# Run: 414, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13, max: 36)
#
# Run: 415, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.01, max: 36)
#
# Run: 416, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.96, max: 36)
#
# Run: 417, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.83, max: 36)
#
# Run: 418, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.82, max: 36)
#
# Run: 419, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.8, max: 36)
#
# Run: 420, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.61, max: 36)
#
# Run: 421, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.44, max: 36)
#
# Run: 422, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.44, max: 36)
#
# Run: 423, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.41, max: 36)
#
# Run: 424, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.48, max: 36)
#
# Run: 425, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.48, max: 36)
#
# Run: 426, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.48, max: 36)
#
# Run: 427, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.46, max: 36)
#
# Run: 428, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.27, max: 31)
#
# Run: 429, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.31, max: 31)
#
# Run: 430, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.34, max: 31)
#
# Run: 431, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.34, max: 31)
#
# Run: 432, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.34, max: 31)
#
# Run: 433, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.32, max: 31)
#
# Run: 434, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.33, max: 31)
#
# Run: 435, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.29, max: 31)
#
# Run: 436, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.25, max: 31)
#
# Run: 437, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.28, max: 31)
#
# Run: 438, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.25, max: 31)
#
# Run: 439, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.25, max: 31)
#
# Run: 440, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.27, max: 31)
#
# Run: 441, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.27, max: 31)
#
# Run: 442, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.07, max: 31)
#
# Run: 443, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.16, max: 31)
#
# Run: 444, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.18, max: 31)
#
# Run: 445, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.13, max: 31)
#
# Run: 446, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.15, max: 31)
#
# Run: 447, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.13, max: 31)
#
# Run: 448, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.19, max: 31)
#
# Run: 449, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.26, max: 31)
#
# Run: 450, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.27, max: 31)
#
# Run: 451, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.2, max: 31)
#
# Run: 452, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.18, max: 31)
#
# Run: 453, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.06, max: 31)
#
# Run: 454, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.07, max: 31)
#
# Run: 455, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.18, max: 31)
#
# Run: 456, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.19, max: 31)
#
# Run: 457, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.14, max: 31)
#
# Run: 458, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.17, max: 31)
#
# Run: 459, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.06, max: 31)
#
# Run: 460, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.12, max: 31)
#
# Run: 461, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.16, max: 31)
#
# Run: 462, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.06, max: 31)
#
# Run: 463, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.06, max: 31)
#
# Run: 464, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.09, max: 31)
#
# Run: 465, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.11, max: 31)
#
# Run: 466, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.09, max: 31)
#
# Run: 467, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.13, max: 31)
#
# Run: 468, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.15, max: 31)
#
# Run: 469, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.17, max: 31)
#
# Run: 470, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.17, max: 31)
#
# Run: 471, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.2, max: 31)
#
# Run: 472, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.11, max: 31)
#
# Run: 473, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 12.25, max: 31)
#
# Run: 474, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.23, max: 31)
#
# Run: 475, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.19, max: 31)
#
# Run: 476, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.22, max: 31)
#
# Run: 477, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.25, max: 31)
#
# Run: 478, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.36, max: 31)
#
# Run: 479, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.32, max: 31)
#
# Run: 480, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.31, max: 31)
#
# Run: 481, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.31, max: 31)
#
# Run: 482, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.29, max: 31)
#
# Run: 483, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.21, max: 31)
#
# Run: 484, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.19, max: 31)
#
# Run: 485, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 12.29, max: 33)
#
# Run: 486, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.26, max: 33)
#
# Run: 487, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.29, max: 33)
#
# Run: 488, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.29, max: 33)
#
# Run: 489, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.19, max: 33)
#
# Run: 490, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.05, max: 33)
#
# Run: 491, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.05, max: 33)
#
# Run: 492, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.05, max: 33)
#
# Run: 493, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.06, max: 33)
#
# Run: 494, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.1, max: 33)
#
# Run: 495, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.19, max: 33)
#
# Run: 496, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.18, max: 33)
#
# Run: 497, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.2, max: 33)
#
# Run: 498, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.25, max: 33)
#
# Run: 499, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.25, max: 33)
#
# Run: 500, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.3, max: 33)
#
# Run: 501, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.42, max: 33)
#
# Run: 502, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.54, max: 33)
#
# Run: 503, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.54, max: 33)
#
# Run: 504, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.5, max: 33)
#
# Run: 505, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.48, max: 33)
#
# Run: 506, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.49, max: 33)
#
# Run: 507, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.48, max: 33)
#
# Run: 508, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.43, max: 33)
#
# Run: 509, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.21, max: 33)
#
# Run: 510, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.24, max: 33)
#
# Run: 511, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.19, max: 33)
#
# Run: 512, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.27, max: 33)
#
# Run: 513, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.33, max: 33)
#
# Run: 514, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.32, max: 33)
#
# Run: 515, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.31, max: 33)
#
# Run: 516, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.3, max: 33)
#
# Run: 517, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.26, max: 33)
#
# Run: 518, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 12.42, max: 33)
#
# Run: 519, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.46, max: 33)
#
# Run: 520, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.48, max: 33)
#
# Run: 521, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.53, max: 33)
#
# Run: 522, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.52, max: 33)
#
# Run: 523, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.55, max: 33)
#
# Run: 524, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.54, max: 33)
#
# Run: 525, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.55, max: 33)
#
# Run: 526, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.58, max: 33)
#
# Run: 527, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.57, max: 33)
#
# Run: 528, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 12.77, max: 37)
#
# Run: 529, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.71, max: 37)
#
# Run: 530, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.66, max: 37)
#
# Run: 531, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.65, max: 37)
#
# Run: 532, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.64, max: 37)
#
# Run: 533, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.75, max: 37)
#
# Run: 534, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.76, max: 37)
#
# Run: 535, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.77, max: 37)
#
# Run: 536, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.76, max: 37)
#
# Run: 537, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.77, max: 37)
#
# Run: 538, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.8, max: 37)
#
# Run: 539, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.8, max: 37)
#
# Run: 540, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.86, max: 37)
#
# Run: 541, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.88, max: 37)
#
# Run: 542, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.87, max: 37)
#
# Run: 543, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.82, max: 37)
#
# Run: 544, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 13.03, max: 37)
#
# Run: 545, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.04, max: 37)
#
# Run: 546, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 13.27, max: 37)
#
# Run: 547, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.28, max: 37)
#
# Run: 548, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.19, max: 37)
#
# Run: 549, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.09, max: 37)
#
# Run: 550, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 13.24, max: 37)
#
# Run: 551, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.2, max: 37)
#
# Run: 552, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.21, max: 37)
#
# Run: 553, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.22, max: 37)
#
# Run: 554, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.2, max: 37)
#
# Run: 555, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 13.24, max: 37)
#
# Run: 556, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.23, max: 37)
#
# Run: 557, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.22, max: 37)
#
# Run: 558, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.18, max: 37)
#
# Run: 559, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.28, max: 37)
#
# Run: 560, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.19, max: 37)
#
# Run: 561, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.15, max: 37)
#
# Run: 562, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 13.35, max: 37)
#
# Run: 563, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.47, max: 37)
#
# Run: 564, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.44, max: 37)
#
# Run: 565, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.41, max: 37)
#
# Run: 566, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.41, max: 37)
#
# Run: 567, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.4, max: 37)
#
# Run: 568, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.4, max: 37)
#
# Run: 569, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.39, max: 37)
#
# Run: 570, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.44, max: 37)
#
# Run: 571, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.41, max: 37)
#
# Run: 572, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.41, max: 37)
#
# Run: 573, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.26, max: 37)
#
# Run: 574, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.29, max: 37)
#
# Run: 575, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.28, max: 37)
#
# Run: 576, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.29, max: 37)
#
# Run: 577, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 13.58, max: 41)
#
# Run: 578, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 13.56, max: 41)
#
# Run: 579, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.58, max: 41)
#
# Run: 580, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.59, max: 41)
#
# Run: 581, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.58, max: 41)
#
# Run: 582, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.55, max: 41)
#
# Run: 583, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.54, max: 41)
#
# Run: 584, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.55, max: 41)
#
# Run: 585, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.31, max: 41)
#
# Run: 586, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.3, max: 41)
#
# Run: 587, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.28, max: 41)
#
# Run: 588, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.29, max: 41)
#
# Run: 589, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.28, max: 41)
#
# Run: 590, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.28, max: 41)
#
# Run: 591, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.3, max: 41)
#
# Run: 592, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.32, max: 41)
#
# Run: 593, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 13.56, max: 41)
#
# Run: 594, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.52, max: 41)
#
# Run: 595, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.41, max: 41)
#
# Run: 596, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.42, max: 41)
#
# Run: 597, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.44, max: 41)
#
# Run: 598, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.44, max: 41)
#
# ...
# Scores: (min: 8, avg: 13.2, max: 41)
#
# Run: 669, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 13.36, max: 41)
#
# Run: 670, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.34, max: 41)
#
# Run: 671, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 13.5, max: 41)
#
# Run: 672, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.49, max: 41)
#
# Run: 673, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.48, max: 41)
#
# Run: 674, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.48, max: 41)
#
# Run: 675, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 13.66, max: 41)
#
# Run: 676, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.63, max: 41)
#
# Run: 677, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.36, max: 35)
#
# Run: 678, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.3, max: 35)
#
# Run: 679, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.32, max: 35)
#
# Run: 680, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.33, max: 35)
#
# Run: 681, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.32, max: 35)
#
# Run: 682, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 13.5, max: 35)
#
# Run: 683, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.49, max: 35)
#
# Run: 684, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.5, max: 35)
#
# Run: 685, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.51, max: 35)
#
# Run: 686, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 13.83, max: 41)
#
# Run: 687, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.82, max: 41)
#
# Run: 688, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.9, max: 41)
#
# Run: 689, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.91, max: 41)
#
# Run: 690, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.94, max: 41)
#
# Run: 691, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.9, max: 41)
#
# Run: 692, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 14.05, max: 41)
#
# Run: 693, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.85, max: 41)
#
# Run: 694, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 13.97, max: 41)
#
# Run: 695, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14, max: 41)
#
# Run: 696, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 14.19, max: 41)
#
# Run: 697, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.23, max: 41)
#
# Run: 698, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.17, max: 41)
#
# Run: 699, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.17, max: 41)
#
# Run: 700, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 14.31, max: 41)
#
# Run: 701, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.29, max: 41)
#
# Run: 702, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 14.44, max: 41)
#
# Run: 703, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.42, max: 41)
#
# Run: 704, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.33, max: 41)
#
# Run: 705, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.36, max: 41)
#
# Run: 706, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.36, max: 41)
#
# Run: 707, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.35, max: 41)
#
# Run: 708, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 14.46, max: 41)
#
# Run: 709, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.36, max: 41)
#
# Run: 710, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 14.56, max: 41)
#
# Run: 711, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 14.74, max: 41)
#
# Run: 712, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.85, max: 41)
#
# Run: 713, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.86, max: 41)
#
# Run: 714, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.85, max: 41)
#
# Run: 715, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.83, max: 41)
#
# Run: 716, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 15.06, max: 41)
#
# Run: 717, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 15.36, max: 41)
#
# Run: 718, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.35, max: 41)
#
# Run: 719, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.42, max: 41)
#
# Run: 720, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.28, max: 41)
#
# Run: 721, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.2, max: 41)
#
# Run: 722, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.19, max: 41)
#
# Run: 723, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.11, max: 41)
#
# Run: 724, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 15.28, max: 41)
#
# Run: 725, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.34, max: 41)
#
# Run: 726, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 15.44, max: 41)
#
# Run: 727, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.47, max: 41)
#
# Run: 728, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 15.57, max: 41)
#
# Run: 729, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 15.85, max: 46)
#
# Run: 730, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 15.97, max: 46)
#
# Run: 731, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.98, max: 46)
#
# Run: 732, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.05, max: 46)
#
# Run: 733, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.06, max: 46)
#
# Run: 734, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 16.28, max: 46)
#
# Run: 735, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 16.44, max: 46)
#
# Run: 736, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 16.6, max: 46)
#
# Run: 737, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.55, max: 46)
#
# Run: 738, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.53, max: 46)
#
# Run: 739, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 16.68, max: 46)
#
# Run: 740, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 17, max: 46)
#
# Run: 741, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.93, max: 46)
#
# Run: 742, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 17.2, max: 46)
#
# Run: 743, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.24, max: 46)
#
# Run: 744, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.24, max: 46)
#
# Run: 745, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.3, max: 46)
#
# Run: 746, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.31, max: 46)
#
# Run: 747, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.32, max: 46)
#
# Run: 748, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 17.54, max: 46)
#
# Run: 749, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.53, max: 46)
#
# Run: 750, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.53, max: 46)
#
# Run: 751, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 17.63, max: 46)
#
# Run: 752, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.59, max: 46)
#
# Run: 753, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 17.9, max: 51)
#
# Run: 754, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.94, max: 51)
#
# Run: 755, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 18.14, max: 51)
#
# Run: 756, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 18.39, max: 51)
#
# Run: 757, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.35, max: 51)
#
# Run: 758, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 18.54, max: 51)
#
# Run: 759, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.55, max: 51)
#
# Run: 760, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.41, max: 51)
#
# Run: 761, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.48, max: 51)
#
# Run: 762, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.29, max: 51)
#
# Run: 763, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.06, max: 51)
#
# Run: 764, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.03, max: 51)
#
# Run: 765, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.01, max: 51)
#
# Run: 766, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.03, max: 51)
#
# Run: 767, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18, max: 51)
#
# Run: 768, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.89, max: 51)
#
# Run: 769, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.74, max: 51)
#
# Run: 770, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.77, max: 51)
#
# Run: 771, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.7, max: 51)
#
# Run: 772, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.7, max: 51)
#
# Run: 773, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.72, max: 51)
#
# Run: 774, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 17.88, max: 51)
#
# Run: 775, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 17.84, max: 51)
#
# Run: 776, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.9, max: 51)
#
# Run: 777, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.92, max: 51)
#
# Run: 778, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 18.15, max: 51)
#
# Run: 779, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.11, max: 51)
#
# Run: 780, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.1, max: 51)
#
# Run: 781, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.11, max: 51)
#
# Run: 782, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 18.13, max: 51)
#
# Run: 783, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.18, max: 51)
#
# Run: 784, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.17, max: 51)
#
# Run: 785, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 18.27, max: 51)
#
# Run: 786, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.95, max: 51)
#
# Run: 787, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18, max: 51)
#
# Run: 788, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.9, max: 51)
#
# Run: 789, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.89, max: 51)
#
# Run: 790, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.86, max: 51)
#
# Run: 791, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.95, max: 51)
#
# Run: 792, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.81, max: 51)
#
# Run: 793, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.76, max: 51)
#
# Run: 794, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.63, max: 51)
#
# Run: 795, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 17.76, max: 51)
#
# Run: 796, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 17.53, max: 51)
#
# Run: 797, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 17.79, max: 51)
#
# Run: 798, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.8, max: 51)
#
# Run: 799, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 18.78, max: 108)
#
# Run: 800, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 18.84, max: 108)
#
# Run: 801, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.87, max: 108)
#
# Run: 802, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 18.73, max: 108)
#
# Run: 803, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.73, max: 108)
#
# Run: 804, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 18.85, max: 108)
#
# Run: 805, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.85, max: 108)
#
# Run: 806, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.93, max: 108)
#
# Run: 807, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.93, max: 108)
#
# Run: 808, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.87, max: 108)
#
# Run: 809, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 18.89, max: 108)
#
# Run: 810, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.68, max: 108)
#
# Run: 811, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.44, max: 108)
#
# Run: 812, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 18.39, max: 108)
#
# Run: 813, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.36, max: 108)
#
# Run: 814, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.39, max: 108)
#
# Run: 815, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.41, max: 108)
#
# Run: 816, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.14, max: 108)
#
# Run: 817, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 17.96, max: 108)
#
# Run: 818, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 18.16, max: 108)
#
# Run: 819, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.17, max: 108)
#
# Run: 820, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.16, max: 108)
#
# Run: 821, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.2, max: 108)
#
# Run: 822, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.18, max: 108)
#
# Run: 823, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.18, max: 108)
#
# Run: 824, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 18.2, max: 108)
#
# Run: 825, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.13, max: 108)
#
# Run: 826, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18, max: 108)
#
# Run: 827, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.95, max: 108)
#
# Run: 828, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.83, max: 108)
#
# Run: 829, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.47, max: 108)
#
# Run: 830, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.33, max: 108)
#
# Run: 831, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.37, max: 108)
#
# Run: 832, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.38, max: 108)
#
# Run: 833, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.37, max: 108)
#
# Run: 834, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.26, max: 108)
#
# Run: 835, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.18, max: 108)
#
# Run: 836, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.98, max: 108)
#
# Run: 837, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.98, max: 108)
#
# Run: 838, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.03, max: 108)
#
# Run: 839, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.82, max: 108)
#
# Run: 840, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.5, max: 108)
#
# Run: 841, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.52, max: 108)
#
# Run: 842, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.23, max: 108)
#
# Run: 843, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.21, max: 108)
#
# Run: 844, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.23, max: 108)
#
# Run: 845, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.18, max: 108)
#
# Run: 846, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.23, max: 108)
#
# Run: 847, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.3, max: 108)
#
# Run: 848, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.06, max: 108)
#
# Run: 849, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.03, max: 108)
#
# Run: 850, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.02, max: 108)
#
# Run: 851, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.87, max: 108)
#
# Run: 852, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.88, max: 108)
#
# Run: 853, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.51, max: 108)
#
# Run: 854, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 15.56, max: 108)
#
# Run: 855, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.34, max: 108)
#
# Run: 856, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 15.29, max: 108)
#
# Run: 857, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.36, max: 108)
#
# Run: 858, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.16, max: 108)
#
# Run: 859, exploration: 0.01, score: 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-5c9b30dec6ab> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      28
#      29     def add_score(self, score, run):
# ---> 30         self._save_csv(SCORES_CSV_PATH, score)
#      31         #self._save_png(input_path=SCORES_CSV_PATH,
#      32         #               output_path=SCORES_PNG_PATH,
#
# U:\Cartpole\scores\score_logger.py in _save_csv(self, path, score)
#      96         with scores_file:
#      97             writer = csv.writer(scores_file)
# ---> 98             writer.writerow([score])
#      99
#
# KeyboardInterrupt:

# %% [markdown]
# changed gamma to 0.05 and saw that the max score to 50 . ran close to 1000 runs. Was running slow with going up and down.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.1  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 13
# Scores: (min: 13, avg: 13, max: 13)
#
# Run: 2, exploration: 0.851801859600347, score: 39
# Scores: (min: 13, avg: 26, max: 39)
#
# Run: 3, exploration: 0.7666961448653229, score: 22
# Scores: (min: 13, avg: 24.666666666666668, max: 39)
#
# Run: 4, exploration: 0.7292124703704616, score: 11
# Scores: (min: 11, avg: 21.25, max: 39)
#
# Run: 5, exploration: 0.6866430931872001, score: 13
# Scores: (min: 11, avg: 19.6, max: 39)
#
# Run: 6, exploration: 0.653073201944699, score: 11
# Scores: (min: 11, avg: 18.166666666666668, max: 39)
#
# Run: 7, exploration: 0.5848838636585911, score: 23
# Scores: (min: 11, avg: 18.857142857142858, max: 39)
#
# Run: 8, exploration: 0.531750826943791, score: 20
# Scores: (min: 11, avg: 19, max: 39)
#
# Run: 9, exploration: 0.4932355662165453, score: 16
# Scores: (min: 11, avg: 18.666666666666668, max: 39)
#
# Run: 10, exploration: 0.46912134373457726, score: 11
# Scores: (min: 11, avg: 17.9, max: 39)
#
# Run: 11, exploration: 0.43952667968844233, score: 14
# Scores: (min: 11, avg: 17.545454545454547, max: 39)
#
# Run: 12, exploration: 0.4180382776616619, score: 11
# Scores: (min: 11, avg: 17, max: 39)
#
# Run: 13, exploration: 0.39166620452737816, score: 14
# Scores: (min: 11, avg: 16.76923076923077, max: 39)
#
# Run: 14, exploration: 0.37251769488706843, score: 11
# Scores: (min: 11, avg: 16.357142857142858, max: 39)
#
# Run: 15, exploration: 0.3302941218954743, score: 25
# Scores: (min: 11, avg: 16.933333333333334, max: 39)
#
# Run: 16, exploration: 0.3173112652388396, score: 9
# Scores: (min: 9, avg: 16.4375, max: 39)
#
# Run: 17, exploration: 0.285607880564032, score: 22
# Scores: (min: 9, avg: 16.764705882352942, max: 39)
#
# Run: 18, exploration: 0.2730095965279488, score: 10
# Scores: (min: 9, avg: 16.38888888888889, max: 39)
#
# Run: 19, exploration: 0.25966219297210513, score: 11
# Scores: (min: 9, avg: 16.105263157894736, max: 39)
#
# Run: 20, exploration: 0.2494556624678441, score: 9
# Scores: (min: 9, avg: 15.75, max: 39)
#
# Run: 21, exploration: 0.2384520680152932, score: 10
# Scores: (min: 9, avg: 15.476190476190476, max: 39)
#
# Run: 22, exploration: 0.22679417751985861, score: 11
# Scores: (min: 9, avg: 15.272727272727273, max: 39)
#
# Run: 23, exploration: 0.2189744609715989, score: 8
# Scores: (min: 8, avg: 14.956521739130435, max: 39)
#
# Run: 24, exploration: 0.20931540516921554, score: 10
# Scores: (min: 8, avg: 14.75, max: 39)
#
# Run: 25, exploration: 0.20209834538617025, score: 8
# Scores: (min: 8, avg: 14.48, max: 39)
#
# Run: 26, exploration: 0.1912566947289212, score: 12
# Scores: (min: 8, avg: 14.384615384615385, max: 39)
#
# Run: 27, exploration: 0.182820281282489, score: 10
# Scores: (min: 8, avg: 14.222222222222221, max: 39)
#
# Run: 28, exploration: 0.1756341724525918, score: 9
# Scores: (min: 8, avg: 14.035714285714286, max: 39)
#
# Run: 29, exploration: 0.16704744067563246, score: 11
# Scores: (min: 8, avg: 13.931034482758621, max: 39)
#
# Run: 30, exploration: 0.15967890763313974, score: 10
# Scores: (min: 8, avg: 13.8, max: 39)
#
# Run: 31, exploration: 0.14229132060898236, score: 24
# Scores: (min: 8, avg: 14.129032258064516, max: 39)
#
# Run: 32, exploration: 0.13738520790976036, score: 8
# Scores: (min: 8, avg: 13.9375, max: 39)
#
# Run: 33, exploration: 0.13264825480308728, score: 8
# Scores: (min: 8, avg: 13.757575757575758, max: 39)
#
# Run: 34, exploration: 0.1255322834371622, score: 12
# Scores: (min: 8, avg: 13.705882352941176, max: 39)
#
# Run: 35, exploration: 0.11999500148501063, score: 10
# Scores: (min: 8, avg: 13.6, max: 39)
#
# Run: 36, exploration: 0.11470197137452155, score: 10
# Scores: (min: 8, avg: 13.5, max: 39)
#
# Run: 37, exploration: 0.10964241905397228, score: 10
# Scores: (min: 8, avg: 13.405405405405405, max: 39)
#
# Run: 38, exploration: 0.1042820154910064, score: 11
# Scores: (min: 8, avg: 13.342105263157896, max: 39)
#
# Run: 39, exploration: 0.09918368135888474, score: 11
# Scores: (min: 8, avg: 13.282051282051283, max: 39)
#
# Run: 40, exploration: 0.09576389217857617, score: 8
# Scores: (min: 8, avg: 13.15, max: 39)
#
# Run: 41, exploration: 0.09199970504166631, score: 9
# Scores: (min: 8, avg: 13.048780487804878, max: 39)
#
# Run: 42, exploration: 0.08838347664452084, score: 9
# Scores: (min: 8, avg: 12.952380952380953, max: 39)
#
# Run: 43, exploration: 0.08448484422350626, score: 10
# Scores: (min: 8, avg: 12.883720930232558, max: 39)
#
# Run: 44, exploration: 0.08075818212241151, score: 10
# Scores: (min: 8, avg: 12.818181818181818, max: 39)
#
# Run: 45, exploration: 0.07719590465791494, score: 10
# Scores: (min: 8, avg: 12.755555555555556, max: 39)
#
# Run: 46, exploration: 0.07416156859737154, score: 9
# Scores: (min: 8, avg: 12.673913043478262, max: 39)
#
# Run: 47, exploration: 0.0716045256805401, score: 8
# Scores: (min: 8, avg: 12.574468085106384, max: 39)
#
# Run: 48, exploration: 0.06844601986126451, score: 10
# Scores: (min: 8, avg: 12.520833333333334, max: 39)
#
# Run: 49, exploration: 0.06477420436570952, score: 12
# Scores: (min: 8, avg: 12.510204081632653, max: 39)
#
# Run: 50, exploration: 0.062228127537270826, score: 9
# Scores: (min: 8, avg: 12.44, max: 39)
#
# Run: 51, exploration: 0.058889873488111255, score: 12
# Scores: (min: 8, avg: 12.431372549019608, max: 39)
#
# Run: 52, exploration: 0.056575091797066025, score: 9
# Scores: (min: 8, avg: 12.365384615384615, max: 39)
#
# Run: 53, exploration: 0.0543512971290831, score: 9
# Scores: (min: 8, avg: 12.30188679245283, max: 39)
#
# Run: 54, exploration: 0.052477299559006776, score: 8
# Scores: (min: 8, avg: 12.222222222222221, max: 39)
#
# Run: 55, exploration: 0.050162503748802344, score: 10
# Scores: (min: 8, avg: 12.181818181818182, max: 39)
#
# Run: 56, exploration: 0.048190768399801194, score: 9
# Scores: (min: 8, avg: 12.125, max: 39)
#
# Run: 57, exploration: 0.046296535966244, score: 9
# Scores: (min: 8, avg: 12.070175438596491, max: 39)
#
# Run: 58, exploration: 0.04425437624418858, score: 10
# Scores: (min: 8, avg: 12.03448275862069, max: 39)
#
# Run: 59, exploration: 0.04209078556329156, score: 11
# Scores: (min: 8, avg: 12.016949152542374, max: 39)
#
# Run: 60, exploration: 0.040032972548509065, score: 11
# Scores: (min: 8, avg: 12, max: 39)
#
# Run: 61, exploration: 0.03826710124979409, score: 10
# Scores: (min: 8, avg: 11.967213114754099, max: 39)
#
# Run: 62, exploration: 0.03621424652392737, score: 12
# Scores: (min: 8, avg: 11.96774193548387, max: 39)
#
# Run: 63, exploration: 0.03359121130473201, score: 16
# Scores: (min: 8, avg: 12.031746031746032, max: 39)
#
# Run: 64, exploration: 0.02904658009432929, score: 30
# Scores: (min: 8, avg: 12.3125, max: 39)
#
# Run: 65, exploration: 0.02707809682994571, score: 15
# Scores: (min: 8, avg: 12.353846153846154, max: 39)
#
# Run: 66, exploration: 0.02562548094765099, score: 12
# Scores: (min: 8, avg: 12.348484848484848, max: 39)
#
# Run: 67, exploration: 0.022835098131175, score: 24
# Scores: (min: 8, avg: 12.522388059701493, max: 39)
#
# Run: 68, exploration: 0.018969543067746772, score: 38
# Scores: (min: 8, avg: 12.897058823529411, max: 39)
#
# Run: 69, exploration: 0.016988875991640028, score: 23
# Scores: (min: 8, avg: 13.043478260869565, max: 39)
#
# Run: 70, exploration: 0.01575835418494799, score: 16
# Scores: (min: 8, avg: 13.085714285714285, max: 39)
#
# Run: 71, exploration: 0.013972200057807112, score: 25
# Scores: (min: 8, avg: 13.253521126760564, max: 39)
#
# Run: 72, exploration: 0.013156542237201536, score: 13
# Scores: (min: 8, avg: 13.25, max: 39)
#
# Run: 73, exploration: 0.01166529436067347, score: 25
# Scores: (min: 8, avg: 13.41095890410959, max: 39)
#
# Run: 74, exploration: 0.01071243191960775, score: 18
# Scores: (min: 8, avg: 13.472972972972974, max: 39)
#
# Run: 75, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 13.746666666666666, max: 39)
#
# Run: 76, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 14, max: 39)
#
# Run: 77, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 14.181818181818182, max: 39)
#
# Run: 78, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 14.717948717948717, max: 56)
#
# Run: 79, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 14.835443037974683, max: 56)
#
# Run: 80, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.8125, max: 56)
#
# Run: 81, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.765432098765432, max: 56)
#
# Run: 82, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.731707317073171, max: 56)
#
# Run: 83, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.674698795180722, max: 56)
#
# Run: 84, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.642857142857142, max: 56)
#
# Run: 85, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.588235294117647, max: 56)
#
# Run: 86, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.55813953488372, max: 56)
#
# Run: 87, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.505747126436782, max: 56)
#
# Run: 88, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.443181818181818, max: 56)
#
# Run: 89, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.404494382022472, max: 56)
#
# Run: 90, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.344444444444445, max: 56)
#
# Run: 91, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.307692307692308, max: 56)
#
# Run: 92, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.23913043478261, max: 56)
#
# Run: 93, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.193548387096774, max: 56)
#
# Run: 94, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.138297872340425, max: 56)
#
# Run: 95, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.073684210526316, max: 56)
#
# Run: 96, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.020833333333334, max: 56)
#
# Run: 97, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.97938144329897, max: 56)
#
# Run: 98, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.938775510204081, max: 56)
#
# Run: 99, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.88888888888889, max: 56)
#
# Run: 100, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.85, max: 56)
#
# Run: 101, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.81, max: 56)
#
# Run: 102, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.52, max: 56)
#
# Run: 103, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.4, max: 56)
#
# Run: 104, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.39, max: 56)
#
# Run: 105, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.35, max: 56)
#
# Run: 106, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.34, max: 56)
#
# Run: 107, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.22, max: 56)
#
# Run: 108, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.12, max: 56)
#
# Run: 109, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.05, max: 56)
#
# Run: 110, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.03, max: 56)
#
# Run: 111, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.98, max: 56)
#
# Run: 112, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.97, max: 56)
#
# Run: 113, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.91, max: 56)
#
# Run: 114, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.9, max: 56)
#
# Run: 115, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.75, max: 56)
#
# Run: 116, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.76, max: 56)
#
# Run: 117, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.64, max: 56)
#
# Run: 118, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.63, max: 56)
#
# Run: 119, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.63, max: 56)
#
# Run: 120, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.64, max: 56)
#
# Run: 121, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.64, max: 56)
#
# Run: 122, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.62, max: 56)
#
# Run: 123, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.64, max: 56)
#
# Run: 124, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.63, max: 56)
#
# Run: 125, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.65, max: 56)
#
# Run: 126, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.62, max: 56)
#
# Run: 127, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.61, max: 56)
#
# Run: 128, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.62, max: 56)
#
# Run: 129, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.6, max: 56)
#
# Run: 130, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.58, max: 56)
#
# Run: 131, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.44, max: 56)
#
# Run: 132, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.44, max: 56)
#
# Run: 133, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.46, max: 56)
#
# Run: 134, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.43, max: 56)
#
# Run: 135, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.43, max: 56)
#
# Run: 136, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.44, max: 56)
#
# Run: 137, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.43, max: 56)
#
# Run: 138, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.42, max: 56)
#
# Run: 139, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.41, max: 56)
#
# Run: 140, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.42, max: 56)
#
# Run: 141, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.42, max: 56)
#
# Run: 142, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.43, max: 56)
#
# Run: 143, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.42, max: 56)
#
# Run: 144, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.42, max: 56)
#
# Run: 145, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.44, max: 56)
#
# Run: 146, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.45, max: 56)
#
# Run: 147, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.47, max: 56)
#
# Run: 148, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.45, max: 56)
#
# Run: 149, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.44, max: 56)
#
# Run: 150, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.45, max: 56)
#
# Run: 151, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.43, max: 56)
#
# Run: 152, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.43, max: 56)
#
# Run: 153, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.42, max: 56)
#
# Run: 154, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.44, max: 56)
#
# Run: 155, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.44, max: 56)
#
# Run: 156, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.44, max: 56)
#
# Run: 157, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.45, max: 56)
#
# Run: 158, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.45, max: 56)
#
# Run: 159, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.43, max: 56)
#
# Run: 160, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.41, max: 56)
#
# Run: 161, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.4, max: 56)
#
# Run: 162, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.36, max: 56)
#
# Run: 163, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.29, max: 56)
#
# Run: 164, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.08, max: 56)
#
# Run: 165, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.03, max: 56)
#
# Run: 166, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.01, max: 56)
#
# Run: 167, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.87, max: 56)
#
# Run: 168, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.57, max: 56)
#
# Run: 169, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.44, max: 56)
#
# Run: 170, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.37, max: 56)
#
# Run: 171, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.2, max: 56)
#
# Run: 172, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.15, max: 56)
#
# Run: 173, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.99, max: 56)
#
# Run: 174, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 10.97, max: 56)
#
# Run: 175, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.77, max: 56)
#
# Run: 176, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.53, max: 56)
#
# Run: 177, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.35, max: 56)
#
# Run: 178, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.88, max: 24)
#
# Run: 179, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.73, max: 16)
#
# Run: 180, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 9.8, max: 20)
#
# Run: 181, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.77, max: 20)
#
# Run: 182, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.74, max: 20)
#
# Run: 183, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.73, max: 20)
#
# Run: 184, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.71, max: 20)
#
# Run: 185, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 9.8, max: 20)
#
# Run: 186, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.78, max: 20)
#
# Run: 187, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 9.84, max: 20)
#
# Run: 188, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.85, max: 20)
#
# Run: 189, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.83, max: 20)
#
# Run: 190, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.85, max: 20)
#
# Run: 191, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.86, max: 20)
#
# Run: 192, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 10.03, max: 25)
#
# Run: 193, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.03, max: 25)
#
# Run: 194, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.04, max: 25)
#
# Run: 195, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.07, max: 25)
#
# Run: 196, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.08, max: 25)
#
# Run: 197, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.07, max: 25)
#
# Run: 198, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 10.26, max: 29)
#
# Run: 199, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 10.34, max: 29)
#
# Run: 200, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.32, max: 29)
#
# Run: 201, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.35, max: 29)
#
# Run: 202, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.36, max: 29)
#
# Run: 203, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 10.45, max: 29)
#
# Run: 204, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.45, max: 29)
#
# Run: 205, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.46, max: 29)
#
# Run: 206, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.49, max: 29)
#
# Run: 207, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.46, max: 29)
#
# Run: 208, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.44, max: 29)
#
# Run: 209, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.45, max: 29)
#
# Run: 210, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.46, max: 29)
#
# Run: 211, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.49, max: 29)
#
# Run: 212, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.48, max: 29)
#
# Run: 213, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.53, max: 29)
#
# Run: 214, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.52, max: 29)
#
# Run: 215, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.52, max: 29)
#
# Run: 216, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.52, max: 29)
#
# Run: 217, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.51, max: 29)
#
# Run: 218, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 10.74, max: 32)
#
# Run: 219, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.73, max: 32)
#
# Run: 220, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.78, max: 32)
#
# Run: 221, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.8, max: 32)
#
# Run: 222, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 10.88, max: 32)
#
# Run: 223, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.89, max: 32)
#
# Run: 224, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.91, max: 32)
#
# Run: 225, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.99, max: 32)
#
# Run: 226, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.01, max: 32)
#
# Run: 227, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.02, max: 32)
#
# Run: 228, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.17, max: 32)
#
# Run: 229, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.18, max: 32)
#
# Run: 230, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 11.4, max: 32)
#
# Run: 231, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.4, max: 32)
#
# Run: 232, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.41, max: 32)
#
# Run: 233, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.44, max: 32)
#
# Run: 234, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.48, max: 32)
#
# Run: 235, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.54, max: 32)
#
# Run: 236, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.51, max: 32)
#
# Run: 237, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.52, max: 32)
#
# Run: 238, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.51, max: 32)
#
# Run: 239, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.52, max: 32)
#
# Run: 240, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 11.71, max: 32)
#
# Run: 241, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 12.19, max: 57)
#
# Run: 242, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.18, max: 57)
#
# Run: 243, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.18, max: 57)
#
# Run: 244, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.3, max: 57)
#
# Run: 245, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 12.42, max: 57)
#
# Run: 246, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.42, max: 57)
#
# Run: 247, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.42, max: 57)
#
# Run: 248, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.57, max: 57)
#
# Run: 249, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.55, max: 57)
#
# Run: 250, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.56, max: 57)
#
# Run: 251, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.55, max: 57)
#
# Run: 252, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.58, max: 57)
#
# Run: 253, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.6, max: 57)
#
# Run: 254, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.59, max: 57)
#
# Run: 255, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.61, max: 57)
#
# Run: 256, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.62, max: 57)
#
# Run: 257, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.67, max: 57)
#
# Run: 258, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 12.96, max: 57)
#
# Run: 259, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.99, max: 57)
#
# Run: 260, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 13.2, max: 57)
#
# Run: 261, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.31, max: 57)
#
# Run: 262, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.4, max: 57)
#
# Run: 263, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.41, max: 57)
#
# Run: 264, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.44, max: 57)
#
# Run: 265, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.45, max: 57)
#
# Run: 266, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 13.73, max: 57)
#
# Run: 267, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.75, max: 57)
#
# Run: 268, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.81, max: 57)
#
# Run: 269, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 13.89, max: 57)
#
# Run: 270, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.91, max: 57)
#
# Run: 271, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.91, max: 57)
#
# Run: 272, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.92, max: 57)
#
# Run: 273, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.92, max: 57)
#
# Run: 274, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.85, max: 57)
#
# Run: 275, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.8, max: 57)
#
# Run: 276, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.8, max: 57)
#
# Run: 277, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.81, max: 57)
#
# Run: 278, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.81, max: 57)
#
# Run: 279, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.81, max: 57)
#
# Run: 280, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.69, max: 57)
#
# Run: 281, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.71, max: 57)
#
# Run: 282, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.72, max: 57)
#
# Run: 283, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.71, max: 57)
#
# Run: 284, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.7, max: 57)
#
# Run: 285, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.6, max: 57)
#
# Run: 286, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.59, max: 57)
#
# Run: 287, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.52, max: 57)
#
# Run: 288, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.5, max: 57)
#
# Run: 289, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.5, max: 57)
#
# Run: 290, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.49, max: 57)
#
# Run: 291, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.46, max: 57)
#
# Run: 292, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.31, max: 57)
#
# Run: 293, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.31, max: 57)
#
# Run: 294, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.31, max: 57)
#
# Run: 295, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.3, max: 57)
#
# Run: 296, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.3, max: 57)
#
# Run: 297, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.31, max: 57)
#
# Run: 298, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.12, max: 57)
#
# Run: 299, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.04, max: 57)
#
# Run: 300, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.05, max: 57)
#
# Run: 301, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.02, max: 57)
#
# Run: 302, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.01, max: 57)
#
# Run: 303, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.91, max: 57)
#
# Run: 304, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.89, max: 57)
#
# Run: 305, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.89, max: 57)
#
# Run: 306, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.85, max: 57)
#
# Run: 307, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.86, max: 57)
#
# Run: 308, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.87, max: 57)
#
# Run: 309, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.87, max: 57)
#
# Run: 310, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.86, max: 57)
#
# Run: 311, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.84, max: 57)
#
# Run: 312, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.85, max: 57)
#
# Run: 313, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.8, max: 57)
#
# Run: 314, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.8, max: 57)
#
# Run: 315, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.79, max: 57)
#
# Run: 316, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.78, max: 57)
#
# Run: 317, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.77, max: 57)
#
# Run: 318, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.55, max: 57)
#
# Run: 319, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.54, max: 57)
#
# Run: 320, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.48, max: 57)
#
# Run: 321, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.45, max: 57)
#
# Run: 322, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.37, max: 57)
#
# Run: 323, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.36, max: 57)
#
# Run: 324, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.34, max: 57)
#
# Run: 325, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.25, max: 57)
#
# Run: 326, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.23, max: 57)
#
# Run: 327, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.23, max: 57)
#
# Run: 328, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.07, max: 57)
#
# Run: 329, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.05, max: 57)
#
# Run: 330, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.85, max: 57)
#
# Run: 331, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.86, max: 57)
#
# Run: 332, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.86, max: 57)
#
# Run: 333, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.82, max: 57)
#
# Run: 334, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.79, max: 57)
#
# Run: 335, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.83, max: 57)
#
# Run: 336, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.97, max: 57)
#
# Run: 337, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.1, max: 57)
#
# Run: 338, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.11, max: 57)
#
# Run: 339, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.17, max: 57)
#
# Run: 340, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.98, max: 57)
#
# Run: 341, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.56, max: 39)
#
# Run: 342, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.58, max: 39)
#
# Run: 343, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.72, max: 39)
#
# Run: 344, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.64, max: 39)
#
# Run: 345, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.54, max: 39)
#
# Run: 346, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.64, max: 39)
#
# Run: 347, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 11.78, max: 39)
#
# Run: 348, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.66, max: 39)
#
# Run: 349, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.72, max: 39)
#
# Run: 350, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.77, max: 39)
#
# Run: 351, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.81, max: 39)
#
# Run: 352, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.84, max: 39)
#
# Run: 353, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.85, max: 39)
#
# Run: 354, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.87, max: 39)
#
# Run: 355, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.89, max: 39)
#
# Run: 356, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.89, max: 39)
#
# Run: 357, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.96, max: 39)
#
# Run: 358, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.68, max: 38)
#
# Run: 359, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.68, max: 38)
#
# Run: 360, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.52, max: 38)
#
# Run: 361, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.43, max: 38)
#
# Run: 362, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 11.53, max: 38)
#
# Run: 363, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 11.67, max: 38)
#
# Run: 364, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.63, max: 38)
#
# Run: 365, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.61, max: 38)
#
# Run: 366, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 11.6, max: 37)
#
# Run: 367, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.6, max: 37)
#
# Run: 368, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.63, max: 37)
#
# Run: 369, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.59, max: 37)
#
# Run: 370, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.6, max: 37)
#
# Run: 371, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.67, max: 37)
#
# Run: 372, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.67, max: 37)
#
# Run: 373, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.68, max: 37)
#
# Run: 374, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.73, max: 37)
#
# Run: 375, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.78, max: 37)
#
# Run: 376, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.81, max: 37)
#
# Run: 377, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.79, max: 37)
#
# Run: 378, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.89, max: 37)
#
# Run: 379, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.89, max: 37)
#
# Run: 380, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.9, max: 37)
#
# Run: 381, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.91, max: 37)
#
# Run: 382, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 12.48, max: 67)
#
# Run: 383, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.56, max: 67)
#
# Run: 384, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.56, max: 67)
#
# Run: 385, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 12.79, max: 67)
#
# Run: 386, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.81, max: 67)
#
# Run: 387, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.83, max: 67)
#
# Run: 388, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 13, max: 67)
#
# Run: 389, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.15, max: 67)
#
# Run: 390, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.14, max: 67)
#
# Run: 391, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.2, max: 67)
#
# Run: 392, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.27, max: 67)
#
# Run: 393, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.25, max: 67)
#
# Run: 394, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.23, max: 67)
#
# Run: 395, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.28, max: 67)
#
# Run: 396, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.28, max: 67)
#
# Run: 397, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.31, max: 67)
#
# Run: 398, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.36, max: 67)
#
# Run: 399, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.44, max: 67)
#
# Run: 400, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.49, max: 67)
#
# Run: 401, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.51, max: 67)
#
# Run: 402, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.55, max: 67)
#
# Run: 403, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.63, max: 67)
#
# Run: 404, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.69, max: 67)
#
# Run: 405, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.69, max: 67)
#
# Run: 406, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.7, max: 67)
#
# Run: 407, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.81, max: 67)
#
# Run: 408, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.87, max: 67)
#
# Run: 409, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 14.08, max: 67)
#
# Run: 410, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.09, max: 67)
#
# Run: 411, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.12, max: 67)
#
# Run: 412, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.15, max: 67)
#
# Run: 413, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.25, max: 67)
#
# Run: 414, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.25, max: 67)
#
# Run: 415, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.26, max: 67)
#
# Run: 416, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.28, max: 67)
#
# Run: 417, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.31, max: 67)
#
# Run: 418, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.3, max: 67)
#
# Run: 419, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.33, max: 67)
#
# Run: 420, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 14.6, max: 67)
#
# Run: 421, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.64, max: 67)
#
# Run: 422, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 14.82, max: 67)
#
# Run: 423, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.81, max: 67)
#
# Run: 424, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.87, max: 67)
#
# Run: 425, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.93, max: 67)
#
# Run: 426, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.96, max: 67)
#
# Run: 427, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 15.04, max: 67)
#
# Run: 428, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.15, max: 67)
#
# Run: 429, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.22, max: 67)
#
# Run: 430, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.22, max: 67)
#
# Run: 431, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.28, max: 67)
#
# Run: 432, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.3, max: 67)
#
# Run: 433, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.4, max: 67)
#
# Run: 434, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 15.55, max: 67)
#
# Run: 435, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.55, max: 67)
#
# Run: 436, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.42, max: 67)
#
# Run: 437, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.33, max: 67)
#
# Run: 438, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 15.46, max: 67)
#
# Run: 439, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.4, max: 67)
#
# Run: 440, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.43, max: 67)
#
# Run: 441, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 15.78, max: 67)
#
# Run: 442, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 15.88, max: 67)
#
# Run: 443, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.77, max: 67)
#
# Run: 444, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.75, max: 67)
#
# Run: 445, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.7, max: 67)
#
# Run: 446, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.6, max: 67)
#
# Run: 447, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.5, max: 67)
#
# Run: 448, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.55, max: 67)
#
# Run: 449, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.51, max: 67)
#
# Run: 450, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.45, max: 67)
#
# Run: 451, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 15.66, max: 67)
#
# Run: 452, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 16.04, max: 67)
#
# Run: 453, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 16.27, max: 67)
#
# Run: 454, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.32, max: 67)
#
# Run: 455, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 16.44, max: 67)
#
# Run: 456, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.44, max: 67)
#
# Run: 457, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.32, max: 67)
#
# Run: 458, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.36, max: 67)
#
# Run: 459, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.42, max: 67)
#
# Run: 460, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.38, max: 67)
#
# Run: 461, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.42, max: 67)
#
# Run: 462, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.24, max: 67)
#
# Run: 463, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 16.27, max: 67)
#
# Run: 464, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.36, max: 67)
#
# Run: 465, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.38, max: 67)
#
# Run: 466, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.1, max: 67)
#
# Run: 467, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 16.25, max: 67)
#
# Run: 468, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.2, max: 67)
#
# Run: 469, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.14, max: 67)
#
# Run: 470, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.16, max: 67)
#
# Run: 471, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.14, max: 67)
#
# Run: 472, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 16.42, max: 67)
#
# Run: 473, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.48, max: 67)
#
# Run: 474, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.55, max: 67)
#
# Run: 475, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 16.74, max: 67)
#
# Run: 476, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.84, max: 67)
#
# Run: 477, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.89, max: 67)
#
# Run: 478, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.81, max: 67)
#
# Run: 479, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.89, max: 67)
#
# Run: 480, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.9, max: 67)
#
# Run: 481, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.94, max: 67)
#
# Run: 482, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.41, max: 53)
#
# Run: 483, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.37, max: 53)
#
# Run: 484, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.38, max: 53)
#
# Run: 485, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.19, max: 53)
#
# Run: 486, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 16.36, max: 53)
#
# Run: 487, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.37, max: 53)
#
# Run: 488, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.37, max: 53)
#
# Run: 489, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.23, max: 53)
#
# Run: 490, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.25, max: 53)
#
# Run: 491, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 16.46, max: 53)
#
# Run: 492, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 16.71, max: 53)
#
# Run: 493, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.76, max: 53)
#
# Run: 494, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 17.06, max: 53)
#
# Run: 495, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17, max: 53)
#
# Run: 496, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.04, max: 53)
#
# Run: 497, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.11, max: 53)
#
# Run: 498, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.12, max: 53)
#
# Run: 499, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.07, max: 53)
#
# Run: 500, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.11, max: 53)
#
# Run: 501, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.09, max: 53)
#
# Run: 502, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.07, max: 53)
#
# Run: 503, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.1, max: 53)
#
# Run: 504, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.13, max: 53)
#
# Run: 505, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 17.35, max: 53)
#
# Run: 506, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.35, max: 53)
#
# Run: 507, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.45, max: 53)
#
# Run: 508, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.44, max: 53)
#
# Run: 509, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.25, max: 53)
#
# Run: 510, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.45, max: 53)
#
# Run: 511, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.42, max: 53)
#
# Run: 512, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.41, max: 53)
#
# Run: 513, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 17.46, max: 53)
#
# Run: 514, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.54, max: 53)
#
# Run: 515, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.54, max: 53)
#
# Run: 516, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.55, max: 53)
#
# Run: 517, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.58, max: 53)
#
# Run: 518, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.59, max: 53)
#
# Run: 519, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.65, max: 53)
#
# Run: 520, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.4, max: 53)
#
# Run: 521, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.42, max: 53)
#
# Run: 522, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.29, max: 53)
#
# Run: 523, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 17.48, max: 53)
#
# Run: 524, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.48, max: 53)
#
# Run: 525, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.43, max: 53)
#
# Run: 526, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 17.58, max: 53)
#
# Run: 527, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.52, max: 53)
#
# Run: 528, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.43, max: 53)
#
# Run: 529, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.38, max: 53)
#
# Run: 530, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 17.66, max: 53)
#
# Run: 531, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.58, max: 53)
#
# Run: 532, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.59, max: 53)
#
# Run: 533, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.52, max: 53)
#
# Run: 534, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.36, max: 53)
#
# Run: 535, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 17.52, max: 53)
#
# Run: 536, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.61, max: 53)
#
# Run: 537, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 17.69, max: 53)
#
# Run: 538, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.64, max: 53)
#
# Run: 539, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.64, max: 53)
#
# Run: 540, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.61, max: 53)
#
# Run: 541, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 17.46, max: 53)
#
# Run: 542, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.43, max: 53)
#
# Run: 543, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.49, max: 53)
#
# Run: 544, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 17.73, max: 53)
#
# Run: 545, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.75, max: 53)
#
# Run: 546, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.74, max: 53)
#
# Run: 547, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.7, max: 53)
#
# Run: 548, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.65, max: 53)
#
# Run: 549, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 18.05, max: 53)
#
# Run: 550, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.05, max: 53)
#
# Run: 551, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.81, max: 53)
#
# Run: 552, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.58, max: 51)
#
# Run: 553, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.34, max: 51)
#
# Run: 554, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.27, max: 51)
#
# Run: 555, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 17.23, max: 51)
#
# Run: 556, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.23, max: 51)
#
# Run: 557, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.29, max: 51)
#
# Run: 558, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.25, max: 51)
#
# Run: 559, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 17.28, max: 51)
#
# Run: 560, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.34, max: 51)
#
# Run: 561, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.34, max: 51)
#
# Run: 562, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 17.67, max: 51)
#
# Run: 563, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.56, max: 51)
#
# Run: 564, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.54, max: 51)
#
# Run: 565, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.57, max: 51)
#
# Run: 566, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.61, max: 51)
#
# Run: 567, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.5, max: 51)
#
# Run: 568, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 17.88, max: 51)
#
# Run: 569, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 17.92, max: 51)
#
# Run: 570, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 18.08, max: 51)
#
# Run: 571, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 18.36, max: 51)
#
# Run: 572, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 18.09, max: 51)
#
# Run: 573, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 18.07, max: 51)
#
# Run: 574, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 17.99, max: 51)
#
# Run: 575, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 17.81, max: 51)
#
# Run: 576, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 17.73, max: 51)
#
# Run: 577, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 17.67, max: 51)
#
# Run: 578, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 17.96, max: 51)
#
# Run: 579, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.89, max: 51)
#
# Run: 580, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.9, max: 51)
#
# Run: 581, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.84, max: 51)
#
# Run: 582, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.85, max: 51)
#
# Run: 583, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 17.92, max: 51)
#
# Run: 584, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.92, max: 51)
#
# Run: 585, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.89, max: 51)
#
# Run: 586, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.72, max: 51)
#
# Run: 587, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 17.79, max: 51)
#
# Run: 588, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 17.82, max: 51)
#
# Run: 589, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.83, max: 51)
#
# Run: 590, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 17.99, max: 51)
#
# Run: 591, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.73, max: 51)
#
# Run: 592, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.43, max: 51)
#
# Run: 593, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.43, max: 51)
#
# ...
# Scores: (min: 8, avg: 17.96, max: 58)
#
# Run: 1822, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.05, max: 58)
#
# Run: 1823, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 17.95, max: 58)
#
# Run: 1824, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.71, max: 58)
#
# Run: 1825, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 17.62, max: 58)
#
# Run: 1826, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.6, max: 58)
#
# Run: 1827, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.69, max: 58)
#
# Run: 1828, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 17.75, max: 58)
#
# Run: 1829, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 17.66, max: 58)
#
# Run: 1830, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.69, max: 58)
#
# Run: 1831, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 17.73, max: 58)
#
# Run: 1832, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 17.71, max: 58)
#
# Run: 1833, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.63, max: 58)
#
# Run: 1834, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.63, max: 58)
#
# Run: 1835, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.57, max: 58)
#
# Run: 1836, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 17.71, max: 58)
#
# Run: 1837, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.74, max: 58)
#
# Run: 1838, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.56, max: 58)
#
# Run: 1839, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.53, max: 58)
#
# Run: 1840, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.67, max: 58)
#
# Run: 1841, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.66, max: 58)
#
# Run: 1842, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.65, max: 58)
#
# Run: 1843, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.72, max: 58)
#
# Run: 1844, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.73, max: 58)
#
# Run: 1845, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.69, max: 58)
#
# Run: 1846, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.68, max: 58)
#
# Run: 1847, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.53, max: 58)
#
# Run: 1848, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.55, max: 58)
#
# Run: 1849, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.38, max: 58)
#
# Run: 1850, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.02, max: 58)
#
# Run: 1851, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.96, max: 58)
#
# Run: 1852, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.93, max: 58)
#
# Run: 1853, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.92, max: 58)
#
# Run: 1854, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 17.09, max: 58)
#
# Run: 1855, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.12, max: 58)
#
# Run: 1856, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.95, max: 58)
#
# Run: 1857, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.83, max: 58)
#
# Run: 1858, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 16.96, max: 58)
#
# Run: 1859, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.79, max: 58)
#
# Run: 1860, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.57, max: 58)
#
# Run: 1861, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.2, max: 58)
#
# Run: 1862, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 16.25, max: 58)
#
# Run: 1863, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.38, max: 58)
#
# Run: 1864, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.91, max: 42)
#
# Run: 1865, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.68, max: 42)
#
# Run: 1866, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.66, max: 42)
#
# Run: 1867, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.65, max: 42)
#
# Run: 1868, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.63, max: 42)
#
# Run: 1869, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.62, max: 42)
#
# Run: 1870, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.61, max: 42)
#
# Run: 1871, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 15.6, max: 42)
#
# Run: 1872, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.59, max: 42)
#
# Run: 1873, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.56, max: 42)
#
# Run: 1874, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.53, max: 42)
#
# Run: 1875, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.54, max: 42)
#
# Run: 1876, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.56, max: 42)
#
# Run: 1877, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.53, max: 42)
#
# Run: 1878, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 15.63, max: 42)
#
# Run: 1879, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.71, max: 42)
#
# Run: 1880, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.8, max: 42)
#
# Run: 1881, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.9, max: 42)
#
# Run: 1882, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.99, max: 42)
#
# Run: 1883, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.96, max: 42)
#
# Run: 1884, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.7, max: 42)
#
# Run: 1885, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.65, max: 42)
#
# Run: 1886, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.6, max: 42)
#
# Run: 1887, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.6, max: 42)
#
# Run: 1888, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.28, max: 40)
#
# Run: 1889, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.29, max: 40)
#
# Run: 1890, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.26, max: 40)
#
# Run: 1891, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 15.3, max: 40)
#
# Run: 1892, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.09, max: 40)
#
# Run: 1893, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.13, max: 40)
#
# Run: 1894, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.07, max: 40)
#
# Run: 1895, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 15.35, max: 40)
#
# Run: 1896, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.44, max: 40)
#
# Run: 1897, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.41, max: 40)
#
# Run: 1898, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.47, max: 40)
#
# Run: 1899, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.43, max: 40)
#
# Run: 1900, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.43, max: 40)
#
# Run: 1901, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.46, max: 40)
#
# Run: 1902, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.42, max: 40)
#
# Run: 1903, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.44, max: 40)
#
# Run: 1904, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 15.63, max: 40)
#
# Run: 1905, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 15.77, max: 40)
#
# Run: 1906, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.74, max: 40)
#
# Run: 1907, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 15.87, max: 40)
#
# Run: 1908, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.88, max: 40)
#
# Run: 1909, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.92, max: 40)
#
# Run: 1910, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 15.94, max: 40)
#
# Run: 1911, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 16.11, max: 40)
#
# Run: 1912, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 16.22, max: 40)
#
# Run: 1913, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.92, max: 37)
#
# Run: 1914, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.93, max: 37)
#
# Run: 1915, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.84, max: 37)
#
# Run: 1916, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.93, max: 37)
#
# Run: 1917, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.89, max: 37)
#
# Run: 1918, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.9, max: 37)
#
# Run: 1919, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 16.09, max: 37)
#
# Run: 1920, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.1, max: 37)
#
# Run: 1921, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 16.24, max: 37)
#
# Run: 1922, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.17, max: 37)
#
# Run: 1923, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.07, max: 37)
#
# Run: 1924, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.12, max: 37)
#
# Run: 1925, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 16.31, max: 41)
#
# Run: 1926, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.37, max: 41)
#
# Run: 1927, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.28, max: 41)
#
# Run: 1928, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.01, max: 41)
#
# Run: 1929, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.07, max: 41)
#
# Run: 1930, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.03, max: 41)
#
# Run: 1931, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.93, max: 41)
#
# Run: 1932, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.65, max: 41)
#
# Run: 1933, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 15.83, max: 41)
#
# Run: 1934, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.85, max: 41)
#
# Run: 1935, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.95, max: 41)
#
# Run: 1936, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.77, max: 41)
#
# Run: 1937, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 16.01, max: 41)
#
# Run: 1938, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.97, max: 41)
#
# Run: 1939, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 16.13, max: 41)
#
# Run: 1940, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.92, max: 41)
#
# Run: 1941, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.86, max: 41)
#
# Run: 1942, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 15.99, max: 41)
#
# Run: 1943, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.93, max: 41)
#
# Run: 1944, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.86, max: 41)
#
# Run: 1945, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 16.03, max: 41)
#
# Run: 1946, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 16.18, max: 41)
#
# Run: 1947, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 16.28, max: 41)
#
# Run: 1948, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.38, max: 41)
#
# Run: 1949, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.37, max: 41)
#
# Run: 1950, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.39, max: 41)
#
# Run: 1951, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.43, max: 41)
#
# Run: 1952, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 16.74, max: 41)
#
# Run: 1953, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.71, max: 41)
#
# Run: 1954, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.53, max: 41)
#
# Run: 1955, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.53, max: 41)
#
# Run: 1956, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 16.77, max: 41)
#
# Run: 1957, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.71, max: 41)
#
# Run: 1958, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.57, max: 41)
#
# Run: 1959, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.61, max: 41)
#
# Run: 1960, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.6, max: 41)
#
# Run: 1961, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 16.71, max: 41)
#
# Run: 1962, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.52, max: 41)
#
# Run: 1963, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.51, max: 41)
#
# Run: 1964, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.51, max: 41)
#
# Run: 1965, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.52, max: 41)
#
# Run: 1966, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.51, max: 41)
#
# Run: 1967, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.52, max: 41)
#
# Run: 1968, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.53, max: 41)
#
# Run: 1969, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.48, max: 41)
#
# Run: 1970, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.49, max: 41)
#
# Run: 1971, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.34, max: 41)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-4-adc42ee11c60> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-4-adc42ee11c60> in experience_replay(self)
#      54             if not terminal:
#      55                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
# ---> 56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
#      58             self.model.fit(state, q_values, verbose=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# changed leaarning rate. ran close to 2000 times with no solve. max score was 51. would increase slowly and fall.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.90  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 19
# Scores: (min: 19, avg: 19, max: 19)
#
# Run: 2, exploration: 0.16677181699666577, score: 18
# Scores: (min: 18, avg: 18.5, max: 19)
#
# Run: 3, exploration: 0.07178979876918531, score: 9
# Scores: (min: 9, avg: 15.333333333333334, max: 19)
#
# Run: 4, exploration: 0.02781283894436938, score: 10
# Scores: (min: 9, avg: 14, max: 19)
#
# Run: 5, exploration: 0.01077526366430583, score: 10
# Scores: (min: 9, avg: 13.2, max: 19)
#
# Run: 6, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12.5, max: 19)
#
# Run: 7, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 12.142857142857142, max: 19)
#
# Run: 8, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.625, max: 19)
#
# Run: 9, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.333333333333334, max: 19)
#
# Run: 10, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.1, max: 19)
#
# Run: 11, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 14, max: 43)
#
# Run: 12, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 19.666666666666668, max: 82)
#
# Run: 13, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 22.076923076923077, max: 82)
#
# Run: 14, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 21.571428571428573, max: 82)
#
# Run: 15, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 21.333333333333332, max: 82)
#
# Run: 16, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 22.1875, max: 82)
#
# Run: 17, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 23.470588235294116, max: 82)
#
# Run: 18, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 23.5, max: 82)
#
# Run: 19, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 23.42105263157895, max: 82)
#
# Run: 20, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 23.25, max: 82)
#
# Run: 21, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 23.142857142857142, max: 82)
#
# Run: 22, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 24.545454545454547, max: 82)
#
# Run: 23, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 25.217391304347824, max: 82)
#
# Run: 24, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 25.875, max: 82)
#
# Run: 25, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 28.32, max: 87)
#
# Run: 26, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 29.76923076923077, max: 87)
#
# Run: 27, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 31.85185185185185, max: 87)
#
# Run: 28, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 33.92857142857143, max: 90)
#
# Run: 29, exploration: 0.01, score: 255
# Scores: (min: 8, avg: 41.55172413793103, max: 255)
#
# Run: 30, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 44.96666666666667, max: 255)
#
# Run: 31, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 46.70967741935484, max: 255)
#
# Run: 32, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 50.0625, max: 255)
#
# Run: 33, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 53.78787878787879, max: 255)
#
# Run: 34, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 59.05882352941177, max: 255)
#
# Run: 35, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 64.71428571428571, max: 257)
#
# Run: 36, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 68.77777777777777, max: 257)
#
# Run: 37, exploration: 0.01, score: 275
# Scores: (min: 8, avg: 74.35135135135135, max: 275)
#
# Run: 38, exploration: 0.01, score: 387
# Scores: (min: 8, avg: 82.57894736842105, max: 387)
#
# Run: 39, exploration: 0.01, score: 276
# Scores: (min: 8, avg: 87.53846153846153, max: 387)
#
# Run: 40, exploration: 0.01, score: 295
# Scores: (min: 8, avg: 92.725, max: 387)
#
# Run: 41, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 94.5609756097561, max: 387)
#
# Run: 42, exploration: 0.01, score: 380
# Scores: (min: 8, avg: 101.35714285714286, max: 387)
#
# Run: 43, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 103.3953488372093, max: 387)
#
# Run: 44, exploration: 0.01, score: 366
# Scores: (min: 8, avg: 109.36363636363636, max: 387)
#
# Run: 45, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 111.13333333333334, max: 387)
#
# Run: 46, exploration: 0.01, score: 288
# Scores: (min: 8, avg: 114.97826086956522, max: 387)
#
# Run: 47, exploration: 0.01, score: 302
# Scores: (min: 8, avg: 118.95744680851064, max: 387)
#
# Run: 48, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 120.22916666666667, max: 387)
#
# Run: 49, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 121.59183673469387, max: 387)
#
# Run: 50, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 122.48, max: 387)
#
# Run: 51, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 125, max: 387)
#
# Run: 52, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 125.9423076923077, max: 387)
#
# Run: 53, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 127.32075471698113, max: 387)
#
# Run: 54, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 127.68518518518519, max: 387)
#
# Run: 55, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 128.25454545454545, max: 387)
#
# Run: 56, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 129.23214285714286, max: 387)
#
# Run: 57, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 132.40350877192984, max: 387)
#
# Run: 58, exploration: 0.01, score: 294
# Scores: (min: 8, avg: 135.18965517241378, max: 387)
#
# Run: 59, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 136.61016949152543, max: 387)
#
# Run: 60, exploration: 0.01, score: 299
# Scores: (min: 8, avg: 139.31666666666666, max: 387)
#
# Run: 61, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 139.2622950819672, max: 387)
#
# Run: 62, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 139.48387096774192, max: 387)
#
# Run: 63, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 140.11111111111111, max: 387)
#
# Run: 64, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 140.4375, max: 387)
#
# Run: 65, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 140.35384615384615, max: 387)
#
# Run: 66, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 141.13636363636363, max: 387)
#
# Run: 67, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 141.59701492537314, max: 387)
#
# Run: 68, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 141.48529411764707, max: 387)
#
# Run: 69, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 142.65217391304347, max: 387)
#
# Run: 70, exploration: 0.01, score: 247
# Scores: (min: 8, avg: 144.14285714285714, max: 387)
#
# Run: 71, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 143.90140845070422, max: 387)
#
# Run: 72, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 144.81944444444446, max: 387)
#
# Run: 73, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 144.4931506849315, max: 387)
#
# Run: 74, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 144.59459459459458, max: 387)
#
# Run: 75, exploration: 0.01, score: 234
# Scores: (min: 8, avg: 145.78666666666666, max: 387)
#
# Run: 76, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 146.3421052631579, max: 387)
#
# Run: 77, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 145.97402597402598, max: 387)
#
# Run: 78, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 146.66666666666666, max: 387)
#
# Run: 79, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 146.8860759493671, max: 387)
#
# Run: 80, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 146.975, max: 387)
#
# Run: 81, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 146.74074074074073, max: 387)
#
# Run: 82, exploration: 0.01, score: 299
# Scores: (min: 8, avg: 148.59756097560975, max: 387)
#
# Run: 83, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 147.56626506024097, max: 387)
#
# Run: 84, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 145.91666666666666, max: 387)
#
# Run: 85, exploration: 0.01, score: 259
# Scores: (min: 8, avg: 147.24705882352941, max: 387)
#
# Run: 86, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 147.54651162790697, max: 387)
#
# Run: 87, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 147.29885057471265, max: 387)
#
# Run: 88, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 147.64772727272728, max: 387)
#
# Run: 89, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 148.43820224719101, max: 387)
#
# Run: 90, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 148.53333333333333, max: 387)
#
# Run: 91, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 149.23076923076923, max: 387)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-d9c7e611a087> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-1-d9c7e611a087> in experience_replay(self)
#      53             q_update = reward
#      54             if not terminal:
# ---> 55                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# chnaged the decay and got a max of 387 out of 90 runs. score would rise and fall.

# %% [markdown]
# goal: cartpole is a game with a pole and object ontop. it it to be balanced for long time. the peerson will know ow to balance after the end.
# different state values: is the banace ontop of the pole and object.
# possible actions: person can change max, decay, and gamma
# reniforcement: is reinforment of trial and error.
# How does experience relay work: the more expereicne can calculate a better score percentage.
# effect of dicount facotr: is determining the min and ave and max
# neural network: is a q learning
# increasing or decreasing: the learning rate in the q learning is massive in the perfromace
